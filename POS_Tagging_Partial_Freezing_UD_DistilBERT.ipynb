# %%
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# !pip -q install transformers datasets evaluate seqeval accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.2 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("universal_dependencies", "en_ewt")
dataset
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 0.00B [00:00, ?B/s]
# universal_dependencies.py: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_182/3370334398.py in <cell line: 0>()
# ...

# %%
# !pip -q install -U "datasets==2.18.0" "huggingface_hub<0.24"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.8/402.8 kB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 19.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 5.0.0 requires huggingface-hub<2.0,>=1.3.0, but you have huggingface-hub 0.23.5 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.2.0 which is incompatible.
# peft 0.18.1 requires huggingface_hub>=0.25.0, but you have huggingface-hub 0.23.5 which is incompatible.
# diffusers 0.36.0 requires huggingface-hub<2.0,>=0.34.0, but you have huggingface-hub 0.23.5 which is incompatible.
# gradio 5.50.0 requires huggingface-hub<2.0,>=0.33.5, but you have huggingface-hub 0.23.5 which is incompatible.

# %%
# !pip -q install -U "datasets==2.18.0" "huggingface_hub<0.24"

# %%
from datasets import load_dataset
dataset = load_dataset("xtreme", "udpos.English")
dataset
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating test split:   0%|          | 0/5440 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 21253
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 3974
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 5440
#     })
# })

# %%
label_list = dataset["train"].features["pos_tags"].feature.names
label_list, len(label_list)
# Out:
# (['ADJ',
#   'ADP',
#   'ADV',
#   'AUX',
#   'CCONJ',
#   'DET',
#   'INTJ',
#   'NOUN',
#   'NUM',
#   'PART',
#   'PRON',
#   'PROPN',
#   'PUNCT',
#   'SCONJ',
#   'SYM',
#   'VERB',
#   'X'],
#  17)

# %%
from transformers import AutoTokenizer

checkpoint = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1981/3170139886.py in <cell line: 0>()
# ----> 1 from transformers import AutoTokenizer
#       2
#       3 checkpoint = "distilbert-base-uncased"
#       4 tokenizer = AutoTokenizer.from_pretrained(checkpoint)
#
# /usr/local/lib/python3.12/dist-packages/transformers/__init__.py in <module>
#      28
#      29 # Check the dependencies satisfy the minimal versions required.
# ---> 30 from . import dependency_versions_check
#      31 from .utils import (
#      32     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.12/dist-packages/transformers/dependency_versions_check.py in <module>
#      14
#      15 from .dependency_versions_table import deps
# ---> 16 from .utils.versions import require_version, require_version_core
#      17
#      18
#
# ...

# %%
# !pip install -q --upgrade transformers datasets huggingface_hub accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 92.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.7/520.7 kB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.3/596.3 kB 49.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 18.5 MB/s eta 0:00:00

# %%
# !pip install -q --upgrade transformers datasets huggingface_hub accelerate

# %%
import transformers, datasets, huggingface_hub, accelerate
print("transformers:", transformers.__version__)
print("datasets:", datasets.__version__)
print("huggingface_hub:", huggingface_hub.__version__)
print("accelerate:", accelerate.__version__)
# Out:
# transformers: 5.3.0
# datasets: 4.6.1
# huggingface_hub: 1.5.0
# accelerate: 1.13.0

# %%
from datasets import load_dataset

dataset = load_dataset("xtreme", "udpos.English")
dataset
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 21253
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 3974
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags'],
#         num_rows: 5440
#     })
# })

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
tokenizer("Hello world!")
# Out:
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# {'input_ids': [101, 7592, 2088, 999, 102], 'token_type_ids': [0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1]}

# %%
label_list = dataset["train"].features["pos_tags"].feature.names
label_list
# Out:
# ['ADJ',
#  'ADP',
#  'ADV',
#  'AUX',
#  'CCONJ',
#  'DET',
#  'INTJ',
#  'NOUN',
#  'NUM',
#  'PART',
#  'PRON',
#  'PROPN',
#  'PUNCT',
#  'SCONJ',
#  'SYM',
#  'VERB',
#  'X']

# %%
print(dataset["train"][0]["tokens"])
print(dataset["train"][0]["pos_tags"])
print([label_list[i] for i in dataset["train"][0]["pos_tags"]])
# Out:
# ['Aesthetic', 'Appreciation', 'and', 'Spanish', 'Art', ':']
# [0, 7, 4, 0, 7, 12]
# ['ADJ', 'NOUN', 'CCONJ', 'ADJ', 'NOUN', 'PUNCT']

# %%
def tokenize_and_align_labels(examples):
    tokenized_inputs = tokenizer(
        examples["tokens"],
        truncation=True,
        is_split_into_words=True
    )

    labels = []
    for i, word_labels in enumerate(examples["pos_tags"]):
        word_ids = tokenized_inputs.word_ids(batch_index=i)
        previous_word_idx = None
        label_ids = []
        for word_idx in word_ids:
            if word_idx is None:
                label_ids.append(-100)  # ignore special tokens
            elif word_idx != previous_word_idx:
                label_ids.append(word_labels[word_idx])  # first subword gets the label
            else:
                label_ids.append(-100)  # ignore other subwords
            previous_word_idx = word_idx
        labels.append(label_ids)

    tokenized_inputs["labels"] = labels
    return tokenized_inputs

tokenized_dataset = dataset.map(tokenize_and_align_labels, batched=True)
tokenized_dataset
# Out:
# ...
# Map:   0%|          | 0/5440 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['tokens', 'pos_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 21253
#     })
#     validation: Dataset({
#         features: ['tokens', 'pos_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 3974
#     })
#     test: Dataset({
#         features: ['tokens', 'pos_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#         num_rows: 5440
#     })
# })

# %%
small_train = tokenized_dataset["train"].shuffle(seed=42).select(range(2000))
small_val = tokenized_dataset["validation"].shuffle(seed=42).select(range(500))
small_test = tokenized_dataset["test"].shuffle(seed=42).select(range(500))

# %%
from transformers import AutoModelForTokenClassification

num_labels = len(label_list)

model = AutoModelForTokenClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=num_labels
)
# Out:
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForTokenClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_projector.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# classifier.weight       | MISSING    |
# classifier.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
import evaluate
import numpy as np

seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    predictions, labels = p
    predictions = np.argmax(predictions, axis=2)

    true_predictions = [
        [label_list[p] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]
    true_labels = [
        [label_list[l] for (p, l) in zip(prediction, label) if l != -100]
        for prediction, label in zip(predictions, labels)
    ]

    results = seqeval.compute(predictions=true_predictions, references=true_labels)

    return {
        "precision": results["overall_precision"],
        "recall": results["overall_recall"],
        "f1": results["overall_f1"],
        "accuracy": results["overall_accuracy"],
    }

# %%
from transformers import TrainingArguments, Trainer, DataCollatorForTokenClassification

training_args = TrainingArguments(
    output_dir="pos_baseline",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    weight_decay=0.01,
    logging_steps=50,
)

data_collator = DataCollatorForTokenClassification(tokenizer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4989/2609875703.py in <cell line: 0>()
#       1 from transformers import TrainingArguments, Trainer, DataCollatorForTokenClassification
#       2
# ----> 3 training_args = TrainingArguments(
#       4     output_dir="pos_baseline",
#       5     evaluation_strategy="epoch",
#
# TypeError: TrainingArguments.__init__() got an unexpected keyword argument 'evaluation_strategy'

# %%
from transformers import TrainingArguments, Trainer, DataCollatorForTokenClassification

training_args = TrainingArguments(
    output_dir="pos_baseline",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    weight_decay=0.01,
    logging_steps=50,
)

data_collator = DataCollatorForTokenClassification(tokenizer)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=small_train,
    eval_dataset=small_val,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4989/1346648519.py in <cell line: 0>()
# ----> 1 trainer = Trainer(
#       2     model=model,
#       3     args=training_args,
#       4     train_dataset=small_train,
#       5     eval_dataset=small_val,
#
# TypeError: Trainer.__init__() got an unexpected keyword argument 'tokenizer'

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=small_train,
    eval_dataset=small_val,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:30, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.745251</td>
#       <td>0.340709</td>
#       <td>0.902202</td>
#       <td>0.901735</td>
#       <td>0.901968</td>
#       <td>0.915584</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.288222</td>
#       <td>0.261031</td>
#       <td>0.916063</td>
#       <td>0.917012</td>
#       <td>0.916537</td>
#       <td>0.928459</td>
#     </tr>
#   </tbody>
# </table><p>
# ...

# %%
baseline_results = trainer.evaluate(small_test)
baseline_results
# Out:
#     <div>
#
#       <progress value='32' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [32/32 00:02]
#     </div>
# /usr/local/lib/python3.12/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: DET seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.12/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: ADJ seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.12/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PROPN seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# /usr/local/lib/python3.12/dist-packages/seqeval/metrics/sequence_labeling.py:171: UserWarning: PUNCT seems not to be NE tag.
#   warnings.warn('{} seems not to be NE tag.'.format(chunk))
# ...

# %%
small_test = tokenized_dataset["test"].select(range(500))

# %%
small_train = tokenized_dataset["train"].select(range(2000))
small_val   = tokenized_dataset["validation"].select(range(500))

print(small_train)
print(small_val)
print(small_test)
# Out:
# Dataset({
#     features: ['tokens', 'pos_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 2000
# })
# Dataset({
#     features: ['tokens', 'pos_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 500
# })
# Dataset({
#     features: ['tokens', 'pos_tags', 'input_ids', 'token_type_ids', 'attention_mask', 'labels'],
#     num_rows: 500
# })

# %%
label_list = dataset["train"].features["pos_tags"].feature.names
num_labels = len(label_list)

id2label = {i: label for i, label in enumerate(label_list)}
label2id = {label: i for i, label in enumerate(label_list)}

print(num_labels, label_list[:10])
# Out:
# 17 ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART']

# %%
from transformers import AutoModelForTokenClassification

model = AutoModelForTokenClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=num_labels,
    id2label=id2label,
    label2id=label2id
)
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForTokenClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_projector.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# classifier.weight       | MISSING    |
# classifier.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="pos_baseline",
    eval_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=2,
    weight_decay=0.01,
    logging_steps=50,
    report_to="none"
)

# %%
from transformers import DataCollatorForTokenClassification

data_collator = DataCollatorForTokenClassification(tokenizer)

# %%
import numpy as np

def compute_metrics(p):
    preds = np.argmax(p.predictions, axis=-1)
    labels = p.label_ids
    mask = labels != -100
    return {"accuracy": (preds[mask] == labels[mask]).mean().item()}

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=small_train,
    eval_dataset=small_val,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:39, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.722820</td>
#       <td>0.291750</td>
#       <td>0.927024</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.237085</td>
#       <td>0.212176</td>
#       <td>0.942294</td>
#     </tr>
#   </tbody>
# </table><p>
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=250, training_loss=0.7239401092529297, metrics={'train_runtime': 39.9663, 'train_samples_per_second': 100.084, 'train_steps_per_second': 6.255, 'total_flos': 58213574554944.0, 'train_loss': 0.7239401092529297, 'epoch': 2.0})

# %%
baseline_results = trainer.evaluate(small_test)
print(baseline_results)
# Out:
#     <div>
#
#       <progress value='32' max='32' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [32/32 00:00]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_4989/4010113301.py in <cell line: 0>()
# ----> 1 baseline_results = trainer.evaluate(small_test)
#       2 print(baseline_results)
#
# /usr/local/lib/python3.12/dist-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    2600             xm.master_print(met.metrics_report())
#    2601
# -> 2602         self.control = self.callback_handler.on_evaluate(self.args, self.state, self.control, output.metrics)
#    2603
#    2604         self._memory_tracker.stop_and_update_metrics(output.metrics)
#
# ...

# %%
from transformers.utils.notebook import NotebookProgressCallback, NotebookTrainingTracker

trainer.remove_callback(NotebookProgressCallback)
trainer.remove_callback(NotebookTrainingTracker)

baseline_results = trainer.evaluate(small_test)
print(baseline_results)
# Out:
# {'eval_loss': 0.24458234012126923, 'eval_accuracy': 0.930752453653217, 'eval_runtime': 0.8711, 'eval_samples_per_second': 574.005, 'eval_steps_per_second': 36.736, 'epoch': 2.0}

# %%
from transformers import AutoModelForTokenClassification

# fresh model (important: don't reuse the already-trained baseline model)
frozen_model = AutoModelForTokenClassification.from_pretrained(
    "distilbert-base-uncased",
    num_labels=num_labels,
    id2label=id2label,
    label2id=label2id
)

# 1) freeze embeddings
for param in frozen_model.distilbert.embeddings.parameters():
    param.requires_grad = False

# 2) freeze first N transformer layers (DistilBERT has 6: 0..5)
N_FREEZE = 4
for layer in frozen_model.distilbert.transformer.layer[:N_FREEZE]:
    for param in layer.parameters():
        param.requires_grad = False

# quick sanity check: how many parameters will train?
trainable = sum(p.numel() for p in frozen_model.parameters() if p.requires_grad)
total = sum(p.numel() for p in frozen_model.parameters())
print(f"Trainable params: {trainable:,} / {total:,} ({100*trainable/total:.2f}%)")
# Out:
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
# DistilBertForTokenClassification LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |
# ------------------------+------------+-
# vocab_projector.bias    | UNEXPECTED |
# vocab_transform.weight  | UNEXPECTED |
# vocab_layer_norm.weight | UNEXPECTED |
# vocab_layer_norm.bias   | UNEXPECTED |
# vocab_transform.bias    | UNEXPECTED |
# classifier.weight       | MISSING    |
# classifier.bias         | MISSING    |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# Trainable params: 14,188,817 / 66,375,953 (21.38%)

# %%
from transformers import Trainer

trainer_frozen = Trainer(
    model=frozen_model,
    args=training_args,
    train_dataset=small_train,
    eval_dataset=small_val,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer_frozen.train()
# Out:
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 00:33, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.631611</td>
#       <td>1.000900</td>
#       <td>0.750799</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.694568</td>
#       <td>0.617601</td>
#       <td>0.857866</td>
#     </tr>
#   </tbody>
# </table><p>
# ...
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=250, training_loss=1.3146133728027343, metrics={'train_runtime': 33.1478, 'train_samples_per_second': 120.672, 'train_steps_per_second': 7.542, 'total_flos': 58213574554944.0, 'train_loss': 1.3146133728027343, 'epoch': 2.0})

# %%
from transformers.utils.notebook import NotebookProgressCallback, NotebookTrainingTracker

trainer_frozen.remove_callback(NotebookProgressCallback)
trainer_frozen.remove_callback(NotebookTrainingTracker)

frozen_results = trainer_frozen.evaluate(small_test)
print(frozen_results)
# Out:
# {'eval_loss': 0.6344706416130066, 'eval_accuracy': 0.851145038167939, 'eval_runtime': 0.843, 'eval_samples_per_second': 593.147, 'eval_steps_per_second': 37.961, 'epoch': 2.0}

# %%
baseline_acc = 0.930752453653217
frozen_acc   = 0.851145038167939
diff = baseline_acc - frozen_acc

print("Baseline Accuracy:", baseline_acc)
print("Frozen Accuracy:  ", frozen_acc)
print("Accuracy drop:    ", diff, f"({diff*100:.2f} percentage points)")
# Out:
# Baseline Accuracy: 0.930752453653217
# Frozen Accuracy:   0.851145038167939
# Accuracy drop:     0.07960741548527805 (7.96 percentage points)
